# %%
fig, ax = plt.subplots()

# Bar chart of gold medals per country
ax.bar(medals.index, medals["Gold"])

# Set x-axis tick labels to country names (rotated)
ax.set_xticklabels(medals.index, rotation=90)

# Set y-axis label
ax.set_ylabel("Number of medals")

plt.show()

# %%
# Add bars for "Gold" with the label "Gold"
ax.bar(medals.index, medals["Gold"], label="Gold")

# Stack bars for "Silver" on top with label "Silver"
ax.bar(medals.index, medals["Silver"], bottom=medals["Gold"], label="Silver")

# Stack bars for "Bronze" on top of that with label "Bronze"
ax.bar(medals.index, medals["Bronze"], bottom=medals["Gold"] + medals["Silver"], label="Bronze")

# Display the legend
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

# Histogram for rowing
ax.hist(mens_rowing["Weight"])

# Histogram for gymnastics
ax.hist(mens_gymnastics["Weight"])

# Axis labels
ax.set_xlabel("Weight (kg)")
ax.set_ylabel("# of observations")

plt.show()

# %%
fig, ax = plt.subplots()

# Plot a histogram of "Weight" for mens_rowing
ax.hist(mens_rowing["Weight"], label="Rowing", histtype="step", bins=5)

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(mens_gymnastics["Weight"], label="Gymnastics", histtype="step", bins=5)

ax.set_xlabel("Weight (kg)")
ax.set_ylabel("# of observations")

# Add the legend and show the Figure
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Rowing: mean height with std error bar
ax.bar("Rowing",
       mens_rowing["Height"].mean(),
       yerr=mens_rowing["Height"].std())

# Gymnastics: mean height with std error bar
ax.bar("Gymnastics",
       mens_gymnastics["Height"].mean(),
       yerr=mens_gymnastics["Height"].std())

# Axis label
ax.set_ylabel("Height (cm)")

plt.show()

# %%
fig, ax = plt.subplots()

# Seattle data with error bars
ax.errorbar(seattle_weather["MONTH"],
            seattle_weather["MLY-TAVG-NORMAL"],
            yerr=seattle_weather["MLY-TAVG-STDDEV"],
            label="Seattle")

# Austin data with error bars
ax.errorbar(austin_weather["MONTH"],
            austin_weather["MLY-TAVG-NORMAL"],
            yerr=austin_weather["MLY-TAVG-STDDEV"],
            label="Austin")

# Axis label
ax.set_ylabel("Temperature (Fahrenheit)")

plt.show()

# %%
fig, ax = plt.subplots()

# Boxplot for rowing and gymnastics heights
ax.boxplot([mens_rowing["Height"], mens_gymnastics["Height"]])

# Set x-axis tick labels
ax.set_xticklabels(["Rowing", "Gymnastics"])

# Set y-axis label
ax.set_ylabel("Height (cm)")

plt.show()

# %%
fig, ax = plt.subplots()

# Scatter plot of CO2 vs relative temperature
ax.scatter(climate_change["co2"], climate_change["relative_temp"])

# Axis labels
ax.set_xlabel("CO2 (ppm)")
ax.set_ylabel("Relative temperature (C)")

plt.show()

# %%
fig, ax = plt.subplots()

# Scatter plot with time encoded as color
ax.scatter(climate_change["co2"],
           climate_change["relative_temp"],
           c=climate_change.index)

# Axis labels
ax.set_xlabel("CO2 (ppm)")
ax.set_ylabel("Relative temperature (C)")

plt.show()
